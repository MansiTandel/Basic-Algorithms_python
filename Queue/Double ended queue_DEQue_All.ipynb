# %%
# DOUBLE ENDED QUEUE USING ARRAYS

# %%
class DEQueArray:
    
    def __init__(self):
        self._data = []
        
    def __len__(self):
        return len(self._data)
    
    def isempty(self):
        return len(self._data) == 0
    
    def addfirst(self,e):
        self._data.insert(0,e) # inserts at specified index
        
    def addlast(self,e):
        self._data.append(e)  # append appends it at the end
     
    def removefirst(self):
        if self.isempty():
            print("DEQueue is empty so can not remove.")
            return
        return self._data.pop(0)
    
    def removelast(self):
        if self.isempty():
            print("DEQueue is empty so can not remove.")
            return
        return self._data.pop()  # no need to pass anything.pops the last element
    
    def first(self):
        if self.isempty():
            print("DEQueue is empty so can not remove.")
            return
        return self._data[0]
    
    def last(self):
        if self.isempty():
            print("DEQueue is empty so can not remove.")
            return
        return self._data[-1]
    
    
D1=DEQueArray()
D1.addfirst(2)
D1.addfirst(3)
D1.addfirst(4)
D1.addfirst(5)
D1.addfirst(7)

D1.addlast(11)
D1.addlast(44)
print(D1._data)

print(D1.removefirst())
print(D1._data)

print(D1.removelast())
print(D1._data)

print(D1.first())
print(D1.last())

print(D1.isempty())
print(len(D1))
# Out:
# [7, 5, 4, 3, 2, 11, 44]
# 7
# [5, 4, 3, 2, 11, 44]
# 44
# [5, 4, 3, 2, 11]
# 5
# 11
# False
# 5

# %%
# DOUBLE ENDED QUEUE USING LINKED LIST

# %%
class _Node:
    __slots__ = '_element', '_next'

    def __init__(self, element, next):
        self._element = element
        self._next = next

class DEQueLinked:
    def __init__(self):
        self._front = None
        self._rear = None
        self._size = 0

    def __len__(self):
        return self._size

    def isempty(self):
        return self._size == 0

    def addlast(self, e):
        newest = _Node(e, None)
        if self.isempty():
            self._front = newest
        else:
            self._rear._next = newest
        self._rear = newest
        self._size += 1

    def addfirst(self, e):
        newest = _Node(e, None)
        if self.isempty():
            self._front = newest
            self._rear = newest
        else:
            newest._next = self._front
            self._front = newest
        self._size += 1

    def removefirst(self):
        if self.isempty():
            print('DEQue is empty')
            return
        e = self._front._element
        self._front = self._front._next
        self._size -= 1
        if self.isempty():
            self._rear = None
        return e

    def removelast(self):
        if self.isempty():
            print('DEQue is empty')
            return
        p = self._front
        i = 1
        while i < len(self) - 1:
            p = p._next
            i = i + 1
        self._rear = p
        p = p._next
        e = p._element
        self._rear._next = None
        self._size -= 1
        return e

    def first(self):
        if self.isempty():
            print('DEQue is empty')
            return
        return self._front._element

    def last(self):
        if self.isempty():
            print('DEQue is empty')
            return
        return self._rear._element

    def display(self):
        p = self._front
        while p:
            print(p._element,end=' --> ')
            p = p._next
        print()


D = DEQueLinked()
D.addfirst(15)
D.addfirst(20)
D.addlast(7)
D.addlast(1)
D.display()
print('Length:',len(D))
print(D.removefirst())
print(D.removelast())
D.display()
print(D.first())
print(D.last())
# Out:
# 20 --> 15 --> 7 --> 1 -->
# Length: 4
# 20
# 1
# 15 --> 7 -->
# 15
# 7
